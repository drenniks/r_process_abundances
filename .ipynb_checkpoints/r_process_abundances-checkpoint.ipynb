# %% [markdown]
# https://articles.adsabs.harvard.edu/pdf/1999A%26A...342..881G

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
f = open('Goriely_99_table_3', 'r')
labels = ['Z', 'A', 'Stand', 'Min', 'Max']
lines = []
for line in f.readlines():
    first = (' ').join(line.split(' ')[:5])
    second = (' ').join(line.split(' ')[5:]).split('\n')[0]
    
    lines.append(first)
    if second == '':
        continue
    else:
        lines.append(second)

# %%
lines = np.sort(lines)

# %%
Z = []
A = []
stand = []

for i, j in enumerate(lines):
    split_line = lines[i].split(' ')

    z = split_line[0]
    a = split_line[1]
    s = split_line[2]
    
    Z.append(int(z))
    A.append(int(a))
    stand.append(float(s))

Z = np.array(Z)
A = np.array(A)
stand = np.array(stand)

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(A, stand)
plt.yscale('log')
plt.ylim(1e-3, 1e2)
plt.ylabel('Abundances')
plt.xlabel('Mass Number, A')
plt.title('r-contributions to solar system abundances')
# Out:
# Text(0.5, 1.0, 'r-contributions to solar system abundances')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
solar_Si_abundance = 1e6

# %%
total_r_abundance = np.sum(stand*A)
normalized_r_abundance = total_r_abundance / 1e6

# %%
normalized_r_abundance
# Out:
# 0.0138390864

# %%
## Values from Frebel+23 (https://arxiv.org/pdf/2302.09188.pdf)

norm = 10**(-1.51)

Eu_L09_u = 0.50
Eu_R22_u = 0.38

Ba_L09_u = 2.16
Ba_R22_u = 1.24

## Eu
Eu_Z = 63
Eu_A = 152
Eu_L09 = 10**Eu_L09_u * norm
Eu_R22 = 10**Eu_R22_u * norm

## Ba
Ba_Z = 56
Ba_A = 137
Ba_L09 = 10**Ba_L09_u * norm
Ba_R22 = 10**Ba_R22_u * norm

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(A, stand)
plt.yscale('log')
#plt.ylim(1e-3, 1e2)
plt.scatter(Eu_A, (Eu_L09), color = 'black', label = 'L09')
plt.scatter(Eu_A, (Eu_R22), color = 'red', label = 'R22')
plt.scatter(Ba_A, (Ba_L09), color = 'black')
plt.scatter(Ba_A, (Ba_R22), color = 'red')
plt.ylabel('Abundances')
plt.xlabel('Mass Number, A')
plt.title('r-contributions to solar system abundances')
plt.legend()
